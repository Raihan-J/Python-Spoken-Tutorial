# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihan-J/Python-Spoken-Tutorial/blob/master/Using%20Python%20Modules/Using%20Python%20Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This Code will download the required files..

# !rm sine.*
# !wget https://raw.githubusercontent.com/Raihan-J/Python-Spoken-Tutorial/master/Using%20Python%20Modules/sine.py

# !rm four_plot.*
# !wget  https://raw.githubusercontent.com/Raihan-J/Python-Spoken-Tutorial/master/Using%20Python%20Modules/four_plot.py

# !rm another_fix.*
# !wget https://raw.githubusercontent.com/Raihan-J/Python-Spoken-Tutorial/master/Using%20Python%20Modules/another_fix.py

# %%
# %run four_plot.py

# %%
# %run another_fix.py

# %% [markdown]
# **Assignment-1**

# %%
# %run sine.py
